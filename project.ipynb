# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
# pd.set_option('display.max_rows', None)
# pd.options.display.max_rows = 60
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Raw data 탐색 (null값 처리 및 불필요한 컬럼 제외)

# %%
df = pd.read_csv('new_retail_data.csv')
df[:5]
# Out:
#    Transaction_ID  Customer_ID                 Name                Email  \
# 0       8691788.0      37249.0  Michelle Harrington    Ebony39@gmail.com
# 1       2174773.0      69749.0          Kelsey Hill     Mark36@gmail.com
# 2       6679610.0      30192.0         Scott Jensen    Shane85@gmail.com
# 3       7232460.0      62101.0        Joseph Miller     Mary34@gmail.com
# 4       4983775.0      27901.0        Debra Coleman  Charles30@gmail.com
#
#           Phone                      Address        City            State  \
# 0  1.414787e+09            3959 Amanda Burgs    Dortmund           Berlin
# 1  6.852900e+09           82072 Dawn Centers  Nottingham          England
# 2  8.362160e+09            4133 Young Canyon     Geelong  New South Wales
# 3  2.776752e+09  8148 Thomas Creek Suite 100    Edmonton          Ontario
# 4  9.098268e+09    5813 Lori Ports Suite 269     Bristol          England
#
#    Zipcode    Country   Age  Gender Income Customer_Segment        Date  \
# 0  77985.0    Germany  21.0    Male    Low          Regular   9/18/2023
# 1  99071.0         UK  19.0  Female    Low          Premium  12/31/2023
# 2  75929.0  Australia  48.0    Male    Low          Regular   4/26/2023
# 3  88420.0     Canada  56.0    Male   High          Premium    5/8/2023
# 4  48704.0         UK  22.0    Male    Low          Premium   1/10/2024
#
#      Year      Month      Time  Total_Purchases      Amount  Total_Amount  \
# 0  2023.0  September  22:03:55              3.0  108.028757    324.086270
# 1  2023.0   December   8:42:04              2.0  403.353907    806.707815
# 2  2023.0      April   4:06:29              3.0  354.477600   1063.432799
# 3  2023.0        May  14:55:17              7.0  352.407717   2466.854021
# 4  2024.0    January  16:54:07              2.0  124.276524    248.553049
#
#   Product_Category  Product_Brand Product_Type   Feedback Shipping_Method  \
# 0         Clothing           Nike       Shorts  Excellent        Same-Day
# 1      Electronics        Samsung       Tablet  Excellent        Standard
# 2            Books  Penguin Books   Children's    Average        Same-Day
# 3       Home Decor     Home Depot        Tools  Excellent        Standard
# 4          Grocery         Nestle    Chocolate        Bad        Standard
#
#   Payment_Method Order_Status  Ratings           products
# 0     Debit Card      Shipped      5.0     Cycling shorts
# 1    Credit Card   Processing      4.0         Lenovo Tab
# 2    Credit Card   Processing      2.0   Sports equipment
# 3         PayPal   Processing      4.0      Utility knife
# 4           Cash      Shipped      1.0  Chocolate cookies

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    301677 non-null  float64
#  1   Customer_ID       301702 non-null  float64
#  2   Name              301628 non-null  object
#  3   Email             301663 non-null  object
#  4   Phone             301648 non-null  float64
#  5   Address           301695 non-null  object
#  6   City              301762 non-null  object
#  7   State             301729 non-null  object
#  8   Zipcode           301670 non-null  float64
#  9   Country           301739 non-null  object
#  10  Age               301837 non-null  float64
#  11  Gender            301693 non-null  object
#  12  Income            301720 non-null  object
#  13  Customer_Segment  301795 non-null  object
#  14  Date              301651 non-null  object
#  15  Year              301660 non-null  float64
#  16  Month             301737 non-null  object
#  17  Time              301660 non-null  object
#  18  Total_Purchases   301649 non-null  float64
#  19  Amount            301653 non-null  float64
#  20  Total_Amount      301660 non-null  float64
#  21  Product_Category  301727 non-null  object
#  22  Product_Brand     301729 non-null  object
#  23  Product_Type      302010 non-null  object
#  24  Feedback          301826 non-null  object
#  25  Shipping_Method   301673 non-null  object
#  26  Payment_Method    301713 non-null  object
#  27  Order_Status      301775 non-null  object
#  28  Ratings           301826 non-null  float64
#  29  products          302010 non-null  object
# dtypes: float64(10), object(20)
# memory usage: 69.1+ MB

# %%
# 분석에 불필요한 컬럼 제외
df_notnull = df.drop(columns=['Name', 'Email', 'Phone', 'Address'])
df_notnull[:5]
# Out:
#    Transaction_ID  Customer_ID        City            State  Zipcode  \
# 0       8691788.0      37249.0    Dortmund           Berlin  77985.0
# 1       2174773.0      69749.0  Nottingham          England  99071.0
# 2       6679610.0      30192.0     Geelong  New South Wales  75929.0
# 3       7232460.0      62101.0    Edmonton          Ontario  88420.0
# 4       4983775.0      27901.0     Bristol          England  48704.0
#
#      Country   Age  Gender Income Customer_Segment        Date    Year  \
# 0    Germany  21.0    Male    Low          Regular   9/18/2023  2023.0
# 1         UK  19.0  Female    Low          Premium  12/31/2023  2023.0
# 2  Australia  48.0    Male    Low          Regular   4/26/2023  2023.0
# 3     Canada  56.0    Male   High          Premium    5/8/2023  2023.0
# 4         UK  22.0    Male    Low          Premium   1/10/2024  2024.0
#
#        Month      Time  Total_Purchases      Amount  Total_Amount  \
# 0  September  22:03:55              3.0  108.028757    324.086270
# 1   December   8:42:04              2.0  403.353907    806.707815
# 2      April   4:06:29              3.0  354.477600   1063.432799
# 3        May  14:55:17              7.0  352.407717   2466.854021
# 4    January  16:54:07              2.0  124.276524    248.553049
#
#   Product_Category  Product_Brand Product_Type   Feedback Shipping_Method  \
# 0         Clothing           Nike       Shorts  Excellent        Same-Day
# 1      Electronics        Samsung       Tablet  Excellent        Standard
# 2            Books  Penguin Books   Children's    Average        Same-Day
# 3       Home Decor     Home Depot        Tools  Excellent        Standard
# 4          Grocery         Nestle    Chocolate        Bad        Standard
#
#   Payment_Method Order_Status  Ratings           products
# 0     Debit Card      Shipped      5.0     Cycling shorts
# 1    Credit Card   Processing      4.0         Lenovo Tab
# 2    Credit Card   Processing      2.0   Sports equipment
# 3         PayPal   Processing      4.0      Utility knife
# 4           Cash      Shipped      1.0  Chocolate cookies

# %%
print(df_notnull['Age'].dtype)
# Out:
# float64

# %%
# 결측치 처리 : 데이터형이 float64 이면 0.0으로 치환, 나머지는 Unknown으로 치환
cols = df_notnull.columns.to_list()
for col in cols:
    if df_notnull[col].dtype == 'float64':
        df_notnull[col].fillna(0.0, inplace=True)
    else:
        df_notnull[col].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipykernel_14099/3796784937.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_notnull[col].fillna(0.0, inplace=True)
# /tmp/ipykernel_14099/3796784937.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_notnull[col].fillna('Unknown', inplace=True)

# %%
df_notnull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 26 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    302010 non-null  float64
#  1   Customer_ID       302010 non-null  float64
#  2   City              302010 non-null  object
#  3   State             302010 non-null  object
#  4   Zipcode           302010 non-null  float64
#  5   Country           302010 non-null  object
#  6   Age               302010 non-null  float64
#  7   Gender            302010 non-null  object
#  8   Income            302010 non-null  object
#  9   Customer_Segment  302010 non-null  object
#  10  Date              302010 non-null  object
#  11  Year              302010 non-null  float64
#  12  Month             302010 non-null  object
#  13  Time              302010 non-null  object
#  14  Total_Purchases   302010 non-null  float64
#  15  Amount            302010 non-null  float64
#  16  Total_Amount      302010 non-null  float64
#  17  Product_Category  302010 non-null  object
#  18  Product_Brand     302010 non-null  object
#  19  Product_Type      302010 non-null  object
#  20  Feedback          302010 non-null  object
#  21  Shipping_Method   302010 non-null  object
#  22  Payment_Method    302010 non-null  object
#  23  Order_Status      302010 non-null  object
#  24  Ratings           302010 non-null  float64
#  25  products          302010 non-null  object
# dtypes: float64(9), object(17)
# memory usage: 59.9+ MB

# %%
df_notnull[df_notnull['City'] == 'Unknown'][:5]
# Out:
#        Transaction_ID  Customer_ID     City            State  Zipcode  \
# 30903       5695172.0      65712.0  Unknown          England  67730.0
# 34227       2344287.0      35757.0  Unknown   North Carolina  27436.0
# 36340       6311279.0      69037.0  Unknown         Arkansas  71902.0
# 36701       6364411.0      97562.0  Unknown  New South Wales  85943.0
# 38608       2001432.0      48237.0  Unknown          England  39923.0
#
#          Country   Age  Gender Income Customer_Segment       Date    Year  \
# 30903         UK  22.0    Male   High          Regular  4/13/2023  2023.0
# 34227        USA  22.0  Female    Low          Regular   9/7/2023  2023.0
# 36340        USA  22.0    Male   High          Regular   3/6/2023  2023.0
# 36701  Australia  22.0  Female    Low          Regular  1/29/2024  2024.0
# 38608         UK  22.0    Male   High          Regular   5/1/2023  2023.0
#
#            Month      Time  Total_Purchases      Amount  Total_Amount  \
# 30903      April  20:56:39              6.0   28.185125    169.110749
# 34227  September   6:16:25              4.0  167.815723    671.262893
# 36340      March   3:25:55              8.0  259.063949   2072.511594
# 36701    January  23:41:03              6.0  397.515059   2385.090356
# 38608        May   3:28:14              1.0   81.243538     81.243538
#
#       Product_Category  Product_Brand Product_Type   Feedback Shipping_Method  \
# 30903         Clothing         Adidas       Jacket    Average        Standard
# 34227       Home Decor     Home Depot        Tools  Excellent        Same-Day
# 36340          Grocery      Coca-Cola   Soft Drink    Average        Standard
# 36701            Books  HarperCollins  Non-Fiction  Excellent        Same-Day
# 38608          Grocery      Coca-Cola   Soft Drink    Average        Standard
#
#       Payment_Method Order_Status  Ratings       products
# 30903         PayPal    Delivered      2.0        Peacoat
# 34227         PayPal    Delivered      4.0  Utility knife
# 36340         PayPal    Delivered      2.0    Orange soda
# 36701     Debit Card    Delivered      4.0     Psychology
# 38608     Debit Card    Delivered      2.0     Ginger ale

# %%
# 데이터형변환 float64 --> int64
df_notnull = df_notnull.astype({'Transaction_ID': 'int', 'Customer_ID': 'int',
                                'Zipcode': 'int', 'Age': 'int', 'Year': 'int'})
df_notnull.dtypes
# Out:
# Transaction_ID        int64
# Customer_ID           int64
# City                 object
# State                object
# Zipcode               int64
# Country              object
# Age                   int64
# Gender               object
# Income               object
# Customer_Segment     object
# Date                 object
# Year                  int64
# Month                object
# Time                 object
# Total_Purchases     float64
# Amount              float64
# Total_Amount        float64
# Product_Category     object
# Product_Brand        object
# Product_Type         object
# Feedback             object
# Shipping_Method      object
# Payment_Method       object
# Order_Status         object
# Ratings             float64
# products             object
# dtype: object

# %%
# Transaction_ID: 거래 ID, Zipcode: 우편번호
df_notnull[:3]
# Out:
#    Transaction_ID  Customer_ID        City            State  Zipcode  \
# 0         8691788        37249    Dortmund           Berlin    77985
# 1         2174773        69749  Nottingham          England    99071
# 2         6679610        30192     Geelong  New South Wales    75929
#
#      Country  Age  Gender Income Customer_Segment        Date  Year  \
# 0    Germany   21    Male    Low          Regular   9/18/2023  2023
# 1         UK   19  Female    Low          Premium  12/31/2023  2023
# 2  Australia   48    Male    Low          Regular   4/26/2023  2023
#
#        Month      Time  Total_Purchases      Amount  Total_Amount  \
# 0  September  22:03:55              3.0  108.028757    324.086270
# 1   December   8:42:04              2.0  403.353907    806.707815
# 2      April   4:06:29              3.0  354.477600   1063.432799
#
#   Product_Category  Product_Brand Product_Type   Feedback Shipping_Method  \
# 0         Clothing           Nike       Shorts  Excellent        Same-Day
# 1      Electronics        Samsung       Tablet  Excellent        Standard
# 2            Books  Penguin Books   Children's    Average        Same-Day
#
#   Payment_Method Order_Status  Ratings          products
# 0     Debit Card      Shipped      5.0    Cycling shorts
# 1    Credit Card   Processing      4.0        Lenovo Tab
# 2    Credit Card   Processing      2.0  Sports equipment

# %%
# 컬럼 이름 변경
df_notnull.rename(columns={'Transaction_ID': 'Transaction_ID(구매번호)',
                           'Customer_ID': 'Customer_ID(고객번호)',
                           'City': 'City(시)',
                           'State': 'State(주)',
                           'Zipcode': 'Zipcode(우편번호)',
                           'Country': 'Country(국가)',
                           'Age': 'Age(나이)',
                           'Gender': 'Gender(성별)',
                           'Income': 'Income(소득수준)',
                           'Customer_Segment': 'Customer_Segment(소비등급)',
                           'Date': 'Date(구매날짜)',
                           'Year': 'Year(연도)',
                           'Month': 'Month(월)',
                           'Time': 'Time(시간)',
                           'Total_Purchases': 'Total_Purchases(총구매수)',
                           'Amount': 'Amount(금액)',
                           'Total_Amount': 'Total_Amount(총구매금액)',
                           'Product_Category': 'Product_Category(카테고리)',
                           'Product_Brand': 'Product_Brand(브랜드)',
                           'Product_Type': 'Product_Type(상품유형)',
                           'Feedback': 'Feedback(피드백)',
                           'Shipping_Method': 'Shipping_Method(배송방법)',
                           'Payment_Method': 'Payment_Method(결제방법)',
                           'Order_Status': 'Order_Status(주문상태)',
                           'Ratings': 'Ratings(평점)',
                           'products': 'products(상품명)'}, inplace=True)

# %%
df_notnull[:3]
# Out:
#    Transaction_ID(구매번호)  Customer_ID(고객번호)     City(시)         State(주)  \
# 0               8691788              37249    Dortmund           Berlin
# 1               2174773              69749  Nottingham          England
# 2               6679610              30192     Geelong  New South Wales
#
#    Zipcode(우편번호) Country(국가)  Age(나이) Gender(성별) Income(소득수준)  \
# 0          77985     Germany       21       Male          Low
# 1          99071          UK       19     Female          Low
# 2          75929   Australia       48       Male          Low
#
#   Customer_Segment(소비등급)  Date(구매날짜)  Year(연도)   Month(월)  Time(시간)  \
# 0                Regular   9/18/2023      2023  September  22:03:55
# 1                Premium  12/31/2023      2023   December   8:42:04
# 2                Regular   4/26/2023      2023      April   4:06:29
#
#    Total_Purchases(총구매수)  Amount(금액)  Total_Amount(총구매금액)  \
# 0                    3.0  108.028757           324.086270
# 1                    2.0  403.353907           806.707815
# 2                    3.0  354.477600          1063.432799
#
#   Product_Category(카테고리) Product_Brand(브랜드) Product_Type(상품유형) Feedback(피드백)  \
# 0               Clothing               Nike             Shorts     Excellent
# 1            Electronics            Samsung             Tablet     Excellent
# 2                  Books      Penguin Books         Children's       Average
#
#   Shipping_Method(배송방법) Payment_Method(결제방법) Order_Status(주문상태)  Ratings(평점)  \
# 0              Same-Day           Debit Card            Shipped          5.0
# 1              Standard          Credit Card         Processing          4.0
# 2              Same-Day          Credit Card         Processing          2.0
#
#       products(상품명)
# 0    Cycling shorts
# 1        Lenovo Tab
# 2  Sports equipment

# %%
df_notnull[df_notnull['Age(나이)'] == 0.0][:5]
# Out:
#         Transaction_ID(구매번호)  Customer_ID(고객번호)        City(시)  \
# 232                  3601539              93979     Portsmouth
# 575                  7443430              28320     Portsmouth
# 22330                3565814              32816      Frankfurt
# 168555               1147230              99092          Essen
# 169403               1348389              97823  Oklahoma City
#
#               State(주)  Zipcode(우편번호) Country(국가)  Age(나이) Gender(성별)  \
# 232            England          51469          UK        0     Female
# 575            England          10810          UK        0     Female
# 22330           Berlin           4787     Germany        0     Female
# 168555          Berlin          66220     Germany        0     Female
# 169403  South Carolina          29221         USA        0     Female
#
#        Income(소득수준) Customer_Segment(소비등급)  Date(구매날짜)  Year(연도) Month(월)  \
# 232             Low                Regular    1/9/2024      2024  January
# 575            High                Regular  10/20/2023      2023  October
# 22330           Low                    New   8/16/2023      2023   August
# 168555       Medium                    New   7/12/2023      2023     July
# 169403       Medium                    New   2/16/2024      2024     July
#
#         Time(시간)  Total_Purchases(총구매수)  Amount(금액)  Total_Amount(총구매금액)  \
# 232      8:44:51                   10.0   32.115559           321.155591
# 575      3:59:07                    9.0  211.259930          1901.339367
# 22330   18:33:56                    1.0   84.572575            84.572575
# 168555  17:47:14                    8.0  161.980816          1295.846525
# 169403  17:20:51                    8.0  313.652977          2509.223814
#
#        Product_Category(카테고리) Product_Brand(브랜드) Product_Type(상품유형)  \
# 232                   Grocery          Coca-Cola              Water
# 575                   Grocery             Nestle             Snacks
# 22330                Clothing               Nike              Shoes
# 168555             Home Decor               IKEA        Decorations
# 169403                Grocery          Coca-Cola         Soft Drink
#
#        Feedback(피드백) Shipping_Method(배송방법) Payment_Method(결제방법)  \
# 232          Average              Same-Day          Credit Card
# 575          Average              Same-Day                 Cash
# 22330           Good              Same-Day               PayPal
# 168555          Good               Express                 Cash
# 169403       Average              Same-Day                 Cash
#
#        Order_Status(주문상태)  Ratings(평점)       products(상품명)
# 232               Pending          2.0       Bottled water
# 575            Processing          2.0          Beef jerky
# 22330           Delivered          4.0          High heels
# 168555          Delivered          3.0  Decorative pillows
# 169403          Delivered          2.0                Cola

# %%
# 수정된 데이터프레임을 csv 파일로 저장
df_notnull.to_csv('./new_retail_data_notnull.csv', index=False)

# %% [markdown]
# ### 매출 분석(1) 0701~0703

# %%
df_notnull = pd.read_csv('new_retail_data_notnull.csv')
df_notnull[:3]
# Out:
#    Transaction_ID(구매번호)  Customer_ID(고객번호)     City(시)         State(주)  \
# 0               8691788              37249    Dortmund           Berlin
# 1               2174773              69749  Nottingham          England
# 2               6679610              30192     Geelong  New South Wales
#
#    Zipcode(우편번호) Country(국가)  Age(나이) Gender(성별) Income(소득수준)  \
# 0          77985     Germany       21       Male          Low
# 1          99071          UK       19     Female          Low
# 2          75929   Australia       48       Male          Low
#
#   Customer_Segment(소비등급)  Date(구매날짜)  Year(연도)   Month(월)  Time(시간)  \
# 0                Regular   9/18/2023      2023  September  22:03:55
# 1                Premium  12/31/2023      2023   December   8:42:04
# 2                Regular   4/26/2023      2023      April   4:06:29
#
#    Total_Purchases(총구매수)  Amount(금액)  Total_Amount(총구매금액)  \
# 0                    3.0  108.028757           324.086270
# 1                    2.0  403.353907           806.707815
# 2                    3.0  354.477600          1063.432799
#
#   Product_Category(카테고리) Product_Brand(브랜드) Product_Type(상품유형) Feedback(피드백)  \
# 0               Clothing               Nike             Shorts     Excellent
# 1            Electronics            Samsung             Tablet     Excellent
# 2                  Books      Penguin Books         Children's       Average
#
#   Shipping_Method(배송방법) Payment_Method(결제방법) Order_Status(주문상태)  Ratings(평점)  \
# 0              Same-Day           Debit Card            Shipped          5.0
# 1              Standard          Credit Card         Processing          4.0
# 2              Same-Day          Credit Card         Processing          2.0
#
#       products(상품명)
# 0    Cycling shorts
# 1        Lenovo Tab
# 2  Sports equipment

# %%
# 결측치 및 데이터형 확인
df_notnull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Transaction_ID(구매번호)    302010 non-null  int64
#  1   Customer_ID(고객번호)       302010 non-null  int64
#  2   City(시)                 302010 non-null  object
#  3   State(주)                302010 non-null  object
#  4   Zipcode(우편번호)           302010 non-null  int64
#  5   Country(국가)             302010 non-null  object
#  6   Age(나이)                 302010 non-null  int64
#  7   Gender(성별)              302010 non-null  object
#  8   Income(소득수준)            302010 non-null  object
#  9   Customer_Segment(소비등급)  302010 non-null  object
#  10  Date(구매날짜)              302010 non-null  object
#  11  Year(연도)                302010 non-null  int64
#  12  Month(월)                302010 non-null  object
#  13  Time(시간)                302010 non-null  object
#  14  Total_Purchases(총구매수)   302010 non-null  float64
#  15  Amount(금액)              302010 non-null  float64
#  16  Total_Amount(총구매금액)     302010 non-null  float64
#  17  Product_Category(카테고리)  302010 non-null  object
#  18  Product_Brand(브랜드)      302010 non-null  object
#  19  Product_Type(상품유형)      302010 non-null  object
#  20  Feedback(피드백)           302010 non-null  object
#  21  Shipping_Method(배송방법)   302010 non-null  object
#  22  Payment_Method(결제방법)    302010 non-null  object
#  23  Order_Status(주문상태)      302010 non-null  object
#  24  Ratings(평점)             302010 non-null  float64
#  25  products(상품명)           302010 non-null  object
# dtypes: float64(4), int64(5), object(17)
# memory usage: 59.9+ MB

# %%
df_notnull['Customer_Segment(소비등급)'].unique()
# Out:
# array(['Regular', 'Premium', 'New', 'Unknown'], dtype=object)

# %%
# 소비등급 별 매출 확인
df_notnull.groupby(['Customer_Segment(소비등급)'])[['Total_Amount(총구매금액)']].sum().sort_values('Total_Amount(총구매금액)', ascending=False)
# Out:
#                         Total_Amount(총구매금액)
# Customer_Segment(소비등급)
# Regular                        1.999656e+08
# New                            1.245976e+08
# Premium                        8.767392e+07
# Unknown                        3.285013e+05

# %%
# 소비등급 별 최대 구매수 확인
df_notnull.groupby(['Customer_Segment(소비등급)'])[['Total_Purchases(총구매수)']].max().sort_values('Total_Purchases(총구매수)', ascending=False)
# Out:
#                         Total_Purchases(총구매수)
# Customer_Segment(소비등급)
# New                                      10.0
# Premium                                  10.0
# Regular                                  10.0
# Unknown                                  10.0

# %%
# 소비등급이 Regular인 사람들의 데이터
regular = df_notnull[df_notnull['Customer_Segment(소비등급)'] == 'Regular'].reset_index().iloc[:, 1:]
regular[:3]
# Out:
#    Transaction_ID(구매번호)  Customer_ID(고객번호)     City(시)         State(주)  \
# 0               8691788              37249    Dortmund           Berlin
# 1               6679610              30192     Geelong  New South Wales
# 2               8493213              19136  Portsmouth          England
#
#    Zipcode(우편번호) Country(국가)  Age(나이) Gender(성별) Income(소득수준)  \
# 0          77985     Germany       21       Male          Low
# 1          75929   Australia       48       Male          Low
# 2          59280          UK       64     Female          Low
#
#   Customer_Segment(소비등급) Date(구매날짜)  Year(연도)   Month(월)  Time(시간)  \
# 0                Regular  9/18/2023      2023  September  22:03:55
# 1                Regular  4/26/2023      2023      April   4:06:29
# 2                Regular  7/20/2023      2023       July  23:06:51
#
#    Total_Purchases(총구매수)  Amount(금액)  Total_Amount(총구매금액)  \
# 0                    3.0  108.028757           324.086270
# 1                    3.0  354.477600          1063.432799
# 2                    4.0   90.981870           363.927479
#
#   Product_Category(카테고리) Product_Brand(브랜드) Product_Type(상품유형) Feedback(피드백)  \
# 0               Clothing               Nike             Shorts     Excellent
# 1                  Books      Penguin Books         Children's       Average
# 2             Home Decor         Home Depot              Tools       Average
#
#   Shipping_Method(배송방법) Payment_Method(결제방법) Order_Status(주문상태)  Ratings(평점)  \
# 0              Same-Day           Debit Card            Shipped          5.0
# 1              Same-Day          Credit Card         Processing          2.0
# 2              Standard          Credit Card            Shipped          2.0
#
#       products(상품명)
# 0    Cycling shorts
# 1  Sports equipment
# 2   Screwdriver set

# %%
# 소비등급이 Regular인 사람들의 평점
regular.groupby(['Ratings(평점)'])[['Ratings(평점)']].count()
# Out:
#              Ratings(평점)
# Ratings(평점)
# 0.0                  117
# 1.0                24453
# 2.0                32741
# 3.0                22840
# 4.0                44405
# 5.0                21665

# %%
# 소비등급이 Regular인 사람들의 나이별 총 구매금액
regular.groupby(['Age(나이)'])[['Total_Amount(총구매금액)']].sum().sort_values(by='Total_Amount(총구매금액)', ascending=False)[:5]
# Out:
#          Total_Amount(총구매금액)
# Age(나이)
# 22              2.853114e+07
# 26              2.485344e+07
# 23              1.839983e+07
# 20              1.533136e+07
# 46              1.434075e+07

# %%
regular['Income(소득수준)'].unique()
# Out:
# array(['Low', 'Medium', 'High', 'Unknown'], dtype=object)

# %%
regular.groupby('Income(소득수준)')[['Total_Amount(총구매금액)']].sum().sort_values(by='Total_Amount(총구매금액)', ascending=False)[:5]
# Out:
#               Total_Amount(총구매금액)
# Income(소득수준)
# Medium               8.591920e+07
# High                 6.230327e+07
# Low                  5.159566e+07
# Unknown              1.474737e+05

# %%
regular.groupby('Gender(성별)')[['Total_Amount(총구매금액)']].sum().sort_values(by='Total_Amount(총구매금액)', ascending=False)
# Out:
#             Total_Amount(총구매금액)
# Gender(성별)
# Male               1.269958e+08
# Female             7.276368e+07
# Unknown            2.060937e+05

# %% [markdown]
# 총구매금액이 가장 많은 소비등급이 'Regular'인 사람들은\
# 평점을 4점으로 준 경우가 많았던 것으로 보아 대부분 소비에 만족했고, 다음으로는 평점을 2점으로 준 경우가 많았다.\
# 22세의 소비가 가장 많았고, 다음으로 26세, 23세, 20세, 46세 순으로 20대의 소비가 가장 많은 것으로 보인다.\
# 또한 소득수준이 Medium인 사람들의 소비가 가장 많았으며, 다음으로 High, Low 순이었다.\
# 여성보다 남성의 경우가 소비를 더 많이 하는 것으로 보인다.

# %%
print(len(df_notnull['Age(나이)'].unique()))
df_notnull['Age(나이)'].unique()
# Out:
# 54
# array([21, 19, 48, 56, 22, 58, 29, 46, 25, 64, 31, 53, 32, 43, 69, 49, 61,
#        41, 38, 59, 20, 67, 50, 26, 66, 24, 54, 28, 34, 65, 40, 68, 36, 57,
#        27, 35, 70, 37, 30, 39, 47, 18, 60, 33, 62, 42, 44, 51, 63, 55, 23,
#        52,  0, 45])

# %%
np.min([21, 19, 48, 56, 22, 58, 29, 46, 25, 64, 31, 53, 32, 43, 69, 49, 61,
41, 38, 59, 20, 67, 50, 26, 66, 24, 54, 28, 34, 65, 40, 68, 36, 57,
27, 35, 70, 37, 30, 39, 47, 18, 60, 33, 62, 42, 44, 51, 63, 55, 23,
52, 45])
# Out:
# np.int64(18)

# %%
regular_gender = pd.pivot_table(data=df_notnull, values='Total_Amount(총구매금액)', index='Age(나이)', columns='Gender(성별)', aggfunc='sum').reset_index().iloc[:, :3]
regular_gender
# Out:
# Gender(성별)  Age(나이)        Female          Male
# 0                 0  1.007448e+05  1.374986e+05
# 1                18  7.549663e+05  1.153340e+06
# 2                19  8.533706e+06  1.295121e+07
# 3                20  1.814228e+07  2.782324e+07
# 4                21  4.493319e+06  6.625852e+06
# 5                22  1.265226e+07  1.891162e+07
# 6                23  9.869788e+06  1.475621e+07
# 7                24  3.423195e+06  5.101368e+06
# 8                25  1.441221e+06  2.122088e+06
# 9                26  4.842396e+06  2.863266e+07
# 10               27  1.440843e+06  2.181955e+06
# 11               28  1.464411e+06  2.198951e+06
# 12               29  1.444246e+06  2.162461e+06
# 13               30  1.451096e+06  2.202518e+06
# 14               31  1.313667e+06  2.160044e+06
# 15               32  1.392849e+06  2.095838e+06
# 16               33  1.537083e+06  2.240439e+06
# 17               34  1.114669e+07  1.715991e+07
# 18               35  1.433493e+06  2.164736e+06
# 19               36  1.403275e+06  2.310668e+06
# 20               37  1.410583e+06  2.121860e+06
# 21               38  1.400177e+06  2.126249e+06
# 22               39  1.529106e+06  2.221044e+06
# 23               40  1.470181e+06  2.206243e+06
# 24               41  1.365328e+06  2.251123e+06
# 25               42  1.523522e+06  2.047253e+06
# 26               43  1.593561e+06  2.234823e+06
# 27               44  1.487755e+06  2.188787e+06
# 28               45  1.475732e+06  2.072719e+06
# 29               46  1.699740e+07  2.543227e+07
# 30               47  1.490599e+06  2.129646e+06
# 31               48  2.571366e+06  3.786735e+06
# 32               49  1.420271e+06  2.178787e+06
# 33               50  1.487224e+06  2.098435e+06
# 34               51  1.447927e+06  2.220047e+06
# 35               52  1.548334e+06  2.108675e+06
# 36               53  1.389934e+06  2.159448e+06
# 37               54  1.367941e+06  2.152628e+06
# 38               55  2.976696e+06  4.570799e+06
# 39               56  1.481808e+06  2.254520e+06
# 40               57  1.402438e+06  2.169495e+06
# 41               58  1.485995e+06  2.134500e+06
# 42               59  1.516419e+06  2.260832e+06
# 43               60  1.350499e+06  2.289210e+06
# 44               61  1.406211e+06  2.192425e+06
# 45               62  1.559398e+06  2.123045e+06
# 46               63  1.323476e+06  2.196320e+06
# 47               64  1.485837e+06  2.252153e+06
# 48               65  1.480386e+06  2.130964e+06
# 49               66  1.377890e+06  2.021058e+06
# 50               67  1.384015e+06  2.096185e+06
# 51               68  1.443609e+06  2.261959e+06
# 52               69  1.477737e+06  2.130066e+06
# 53               70  1.535797e+06  2.268950e+06

# %%
more = []
for i in range(len(regular_gender)):
    if regular_gender['Female'][i] > regular_gender['Male'][i]:
        more.append('Female')
    else:
        more.append('Male')

regular_gender['More'] = more
regular_gender[:3]
# Out:
# Gender(성별)  Age(나이)        Female          Male  More
# 0                 0  1.007448e+05  1.374986e+05  Male
# 1                18  7.549663e+05  1.153340e+06  Male
# 2                19  8.533706e+06  1.295121e+07  Male

# %%
print(len(regular_gender[regular_gender['More'] == 'Female']))
print(len(regular_gender[regular_gender['More'] == 'Male']))
# Out:
# 0
# 54

# %% [markdown]
# ### 매출 분석(2) 0704~

# %%
df_notnull = pd.read_csv('new_retail_data_notnull.csv')
df_notnull[:3]
# Out:
#    Transaction_ID(구매번호)  Customer_ID(고객번호)     City(시)         State(주)  \
# 0               8691788              37249    Dortmund           Berlin
# 1               2174773              69749  Nottingham          England
# 2               6679610              30192     Geelong  New South Wales
#
#    Zipcode(우편번호) Country(국가)  Age(나이) Gender(성별) Income(소득수준)  \
# 0          77985     Germany       21       Male          Low
# 1          99071          UK       19     Female          Low
# 2          75929   Australia       48       Male          Low
#
#   Customer_Segment(소비등급)  Date(구매날짜)  Year(연도)   Month(월)  Time(시간)  \
# 0                Regular   9/18/2023      2023  September  22:03:55
# 1                Premium  12/31/2023      2023   December   8:42:04
# 2                Regular   4/26/2023      2023      April   4:06:29
#
#    Total_Purchases(총구매수)  Amount(금액)  Total_Amount(총구매금액)  \
# 0                    3.0  108.028757           324.086270
# 1                    2.0  403.353907           806.707815
# 2                    3.0  354.477600          1063.432799
#
#   Product_Category(카테고리) Product_Brand(브랜드) Product_Type(상품유형) Feedback(피드백)  \
# 0               Clothing               Nike             Shorts     Excellent
# 1            Electronics            Samsung             Tablet     Excellent
# 2                  Books      Penguin Books         Children's       Average
#
#   Shipping_Method(배송방법) Payment_Method(결제방법) Order_Status(주문상태)  Ratings(평점)  \
# 0              Same-Day           Debit Card            Shipped          5.0
# 1              Standard          Credit Card         Processing          4.0
# 2              Same-Day          Credit Card         Processing          2.0
#
#       products(상품명)
# 0    Cycling shorts
# 1        Lenovo Tab
# 2  Sports equipment

# %%
# Year(연도) 값이 0인 경우 Date(구매날짜) 컬럼 값에서 연도 값을 가져와 치환
for i in range(len(df_notnull)):
    if df_notnull['Year(연도)'][i] == 0:
        df_notnull['Year(연도)'][i] = int(df_notnull['Date(구매날짜)'][i][-4:])

df_notnull[df_notnull['Year(연도)'] == 0]
# Out:
# Empty DataFrame
# Columns: [Transaction_ID(구매번호), Customer_ID(고객번호), City(시), State(주), Zipcode(우편번호), Country(국가), Age(나이), Gender(성별), Income(소득수준), Customer_Segment(소비등급), Date(구매날짜), Year(연도), Month(월), Time(시간), Total_Purchases(총구매수), Amount(금액), Total_Amount(총구매금액), Product_Category(카테고리), Product_Brand(브랜드), Product_Type(상품유형), Feedback(피드백), Shipping_Method(배송방법), Payment_Method(결제방법), Order_Status(주문상태), Ratings(평점), products(상품명)]
# Index: []

# %%
df_notnull['Year(연도)'].unique()
# Out:
# array([2023, 2024])

# %%
# 소비등급이 Regular인 사람들의 데이터
regular = df_notnull[df_notnull['Customer_Segment(소비등급)'] == 'Regular'].reset_index().iloc[:, 1:]
regular[:3]
# Out:
#    Transaction_ID(구매번호)  Customer_ID(고객번호)     City(시)         State(주)  \
# 0               8691788              37249    Dortmund           Berlin
# 1               6679610              30192     Geelong  New South Wales
# 2               8493213              19136  Portsmouth          England
#
#    Zipcode(우편번호) Country(국가)  Age(나이) Gender(성별) Income(소득수준)  \
# 0          77985     Germany       21       Male          Low
# 1          75929   Australia       48       Male          Low
# 2          59280          UK       64     Female          Low
#
#   Customer_Segment(소비등급) Date(구매날짜)  Year(연도)   Month(월)  Time(시간)  \
# 0                Regular  9/18/2023      2023  September  22:03:55
# 1                Regular  4/26/2023      2023      April   4:06:29
# 2                Regular  7/20/2023      2023       July  23:06:51
#
#    Total_Purchases(총구매수)  Amount(금액)  Total_Amount(총구매금액)  \
# 0                    3.0  108.028757           324.086270
# 1                    3.0  354.477600          1063.432799
# 2                    4.0   90.981870           363.927479
#
#   Product_Category(카테고리) Product_Brand(브랜드) Product_Type(상품유형) Feedback(피드백)  \
# 0               Clothing               Nike             Shorts     Excellent
# 1                  Books      Penguin Books         Children's       Average
# 2             Home Decor         Home Depot              Tools       Average
#
#   Shipping_Method(배송방법) Payment_Method(결제방법) Order_Status(주문상태)  Ratings(평점)  \
# 0              Same-Day           Debit Card            Shipped          5.0
# 1              Same-Day          Credit Card         Processing          2.0
# 2              Standard          Credit Card            Shipped          2.0
#
#       products(상품명)
# 0    Cycling shorts
# 1  Sports equipment
# 2   Screwdriver set

# %%
# 소비등급 Regular인 사람들의 국가별, 주별 매출비교
regular.groupby('Country(국가)')[['Total_Amount(총구매금액)']].sum().sort_values(by='Total_Amount(총구매금액)', ascending=False)
# Out:
#              Total_Amount(총구매금액)
# Country(국가)
# USA                 6.530286e+07
# UK                  4.921060e+07
# Germany             3.503005e+07
# Australia           2.533955e+07
# Canada              2.496077e+07
# Unknown             1.217768e+05

# %%
regular.groupby('State(주)')[['Total_Amount(총구매금액)']].sum().sort_values(by='Total_Amount(총구매금액)', ascending=False)[:10]
# Out:
#                  Total_Amount(총구매금액)
# State(주)
# England                 4.918889e+07
# Berlin                  3.502733e+07
# New South Wales         2.534971e+07
# Ontario                 2.494669e+07
# Maine                   1.578138e+07
# Georgia                 1.227098e+07
# Connecticut             9.848760e+06
# Kansas                  3.699103e+06
# Florida                 5.746273e+05
# New York                5.634415e+05

# %%
# 연도별, 월별 매출 비교
# regular.groupby(['Year(연도)', 'Month(월)'])[['Total_Amount(총구매금액)']].sum().sort_values(by='Total_Amount(총구매금액)', ascending=False)
# pd.pivot_table(data=regular, values='Total_Amount(총구매금액)', columns='Year(연도)', index='Month(월)', aggfunc='sum')
regular_ym = pd.pivot_table(data=regular, values='Total_Amount(총구매금액)', columns='Year(연도)', index='Month(월)', aggfunc='sum')
regular_ym
# Out:
# Year(연도)           2023          2024
# Month(월)
# April      2.030994e+07  1.656965e+06
# August     1.756684e+07  1.105872e+06
# December   1.221538e+07  1.323900e+04
# February   1.423491e+05  1.137028e+07
# January    1.873655e+07  1.576458e+07
# July       2.273092e+07  2.075015e+06
# June       1.161749e+07  3.965774e+04
# March      1.231856e+07  3.432232e+04
# May        1.573510e+07  7.146992e+05
# November   1.169142e+07  2.944688e+04
# October    1.205034e+07  2.334260e+04
# September  1.182642e+07  2.462482e+04
# Unknown    1.486822e+05  2.358851e+04

# %%
regular_ym.iloc[:, :1].sort_values(by=(2023), ascending=False)[:3]
# Out:
# Year(연도)          2023
# Month(월)
# July      2.273092e+07
# April     2.030994e+07
# January   1.873655e+07

# %%
regular_ym.iloc[:, 1:].sort_values(by=(2024), ascending=False)[:3]
# Out:
# Year(연도)          2024
# Month(월)
# January   1.576458e+07
# February  1.137028e+07
# July      2.075015e+06

# %%
# df_notnull[df_notnull['Year(연도)'] == 0]
df_notnull[df_notnull['Date(구매날짜)'] == 'Unknown']
# Out:
#         Transaction_ID(구매번호)  Customer_ID(고객번호)     City(시) State(주)  \
# 3921                 2771549              59548  Portsmouth  England
# 4342                 2632074              93647  Portsmouth  England
# 5135                 3349514              71021  Portsmouth  England
# 5231                 4043499              17605  Portsmouth  England
# 6857                 9686043              16259  Portsmouth  England
# ...                      ...                ...         ...      ...
# 297935               4204783              22912       Tulsa   Oregon
# 298792               2742967              57511       Essen   Berlin
# 298832               6673065              83349     Bristol  England
# 300441               7126641              61813  Manchester  England
# 300754               6557842              97108   Stuttgart   Berlin
#
#         Zipcode(우편번호) Country(국가)  Age(나이) Gender(성별) Income(소득수준)  \
# 3921            68989          UK       21     Female       Medium
# 4342            24000          UK       24       Male       Medium
# 5135            47239          UK       24     Female       Medium
# 5231            36062          UK       24       Male       Medium
# 6857            72778          UK       24       Male       Medium
# ...               ...         ...      ...        ...          ...
# 297935          97625         USA       50       Male          Low
# 298792          82263     Germany       24     Female         High
# 298832          10611          UK       63       Male       Medium
# 300441          88333          UK       35     Female          Low
# 300754          74405     Germany       20     Female       Medium
#
#        Customer_Segment(소비등급) Date(구매날짜)  Year(연도)  Month(월)  Time(시간)  \
# 3921                  Regular    Unknown      2023  November  18:14:15
# 4342                  Regular    Unknown      2023      July   3:05:25
# 5135                  Regular    Unknown      2023      July  14:01:47
# 5231                  Regular    Unknown      2023      June   6:13:33
# 6857                  Regular    Unknown      2023   October  14:08:34
# ...                       ...        ...       ...       ...       ...
# 297935                Regular    Unknown      2023  December  21:14:27
# 298792                Regular    Unknown      2023     April   3:31:42
# 298832                Premium    Unknown      2023     March  23:47:49
# 300441                Premium    Unknown      2024  February  20:30:33
# 300754                    New    Unknown      2023    August   2:47:10
#
#         Total_Purchases(총구매수)  Amount(금액)  Total_Amount(총구매금액)  \
# 3921                      1.0  292.031675           292.031675
# 4342                      7.0  338.715576          2371.009032
# 5135                      7.0  249.679524          1747.756665
# 5231                      7.0  302.073805          2114.516634
# 6857                      5.0  231.726948          1158.634738
# ...                       ...         ...                  ...
# 297935                    7.0   93.545264           654.816847
# 298792                    8.0  213.317274          1706.538194
# 298832                    4.0  476.360238          1905.440951
# 300441                    5.0  325.208673          1626.043364
# 300754                    1.0  157.350373           157.350373
#
#        Product_Category(카테고리) Product_Brand(브랜드) Product_Type(상품유형)  \
# 3921               Home Decor         Home Depot          Furniture
# 4342                    Books      HarperCollins        Non-Fiction
# 5135                 Clothing               Nike             Shorts
# 5231               Home Decor               IKEA           Lighting
# 6857              Electronics              Apple             Tablet
# ...                       ...                ...                ...
# 297935                Grocery             Nestle             Snacks
# 298792             Home Decor         Home Depot        Decorations
# 298832                  Books       Random House            Fiction
# 300441                  Books       Random House         Literature
# 300754            Electronics            Samsung         Smartphone
#
#        Feedback(피드백) Shipping_Method(배송방법) Payment_Method(결제방법)  \
# 3921         Average              Standard          Credit Card
# 4342             Bad               Express           Debit Card
# 5135             Bad              Standard               PayPal
# 5231             Bad              Standard          Credit Card
# 6857            Good               Express           Debit Card
# ...              ...                   ...                  ...
# 297935     Excellent               Express          Credit Card
# 298792           Bad               Express          Credit Card
# 298832          Good               Express          Credit Card
# 300441     Excellent               Express          Credit Card
# 300754          Good              Same-Day                 Cash
#
#        Order_Status(주문상태)  Ratings(평점)       products(상품명)
# 3921            Delivered          2.0        Dining table
# 4342              Pending          1.0          Psychology
# 5135              Shipped          1.0        Cargo shorts
# 5231              Pending          1.0   Recessed lighting
# 6857            Delivered          4.0  Sony Xperia Tablet
# ...                   ...          ...                 ...
# 297935          Delivered          5.0        Granola bars
# 298792            Shipped          1.0                Rugs
# 298832            Pending          4.0             Romance
# 300441            Shipped          4.0       Short stories
# 300754          Delivered          4.0       Motorola Moto
#
# [359 rows x 26 columns]

# %%
# 상품별 매출비교
pd.pivot_table(data=regular, values='Total_Amount(총구매금액)', columns='Year(연도)', index='Product_Category(카테고리)', aggfunc='sum')
# Out:
# Year(연도)                        2023          2024
# Product_Category(카테고리)
# Books                   3.036783e+07  5.997828e+06
# Clothing                3.046509e+07  5.772087e+06
# Electronics             4.075244e+07  8.066116e+06
# Grocery                 3.491757e+07  6.966978e+06
# Home Decor              3.043808e+07  6.040161e+06
# Unknown                 1.489702e+05  3.245823e+04

# %%
# 브랜드별 매출비교
regular_brand = pd.pivot_table(data=regular, values='Total_Amount(총구매금액)', columns='Year(연도)', index='Product_Brand(브랜드)', aggfunc='sum')
regular_brand
# Out:
# Year(연도)                    2023          2024
# Product_Brand(브랜드)
# Adidas              1.009628e+07  2.002374e+06
# Apple               9.864383e+06  1.929227e+06
# Bed Bath & Beyond   1.039326e+07  2.087936e+06
# BlueStar            8.244586e+05  1.797543e+05
# Coca-Cola           1.017548e+07  2.016731e+06
# HarperCollins       9.979041e+06  2.096644e+06
# Home Depot          9.931823e+06  2.065768e+06
# IKEA                1.009714e+07  1.887507e+06
# Mitsubhisi          2.506599e+06  4.533317e+05
# Nestle              1.010534e+07  2.035031e+06
# Nike                1.013034e+07  1.984125e+06
# Penguin Books       1.012915e+07  1.897026e+06
# Pepsi               1.465529e+07  2.904519e+06
# Random House        1.025221e+07  2.013152e+06
# Samsung             1.020926e+07  2.091340e+06
# Sony                1.012020e+07  1.958490e+06
# Unknown             1.557319e+05  2.556424e+04
# Whirepool           7.225792e+06  1.456388e+06
# Zara                1.023822e+07  1.790721e+06

# %%
regular_brand.iloc[:, :1].sort_values(by=(2023), ascending=False)
# Out:
# Year(연도)                    2023
# Product_Brand(브랜드)
# Pepsi               1.465529e+07
# Bed Bath & Beyond   1.039326e+07
# Random House        1.025221e+07
# Zara                1.023822e+07
# Samsung             1.020926e+07
# Coca-Cola           1.017548e+07
# Nike                1.013034e+07
# Penguin Books       1.012915e+07
# Sony                1.012020e+07
# Nestle              1.010534e+07
# IKEA                1.009714e+07
# Adidas              1.009628e+07
# HarperCollins       9.979041e+06
# Home Depot          9.931823e+06
# Apple               9.864383e+06
# Whirepool           7.225792e+06
# Mitsubhisi          2.506599e+06
# BlueStar            8.244586e+05
# Unknown             1.557319e+05

# %%
regular_brand.iloc[:, 1:].sort_values(by=(2024), ascending=False)
# Out:
# Year(연도)                    2024
# Product_Brand(브랜드)
# Pepsi               2.904519e+06
# HarperCollins       2.096644e+06
# Samsung             2.091340e+06
# Bed Bath & Beyond   2.087936e+06
# Home Depot          2.065768e+06
# Nestle              2.035031e+06
# Coca-Cola           2.016731e+06
# Random House        2.013152e+06
# Adidas              2.002374e+06
# Nike                1.984125e+06
# Sony                1.958490e+06
# Apple               1.929227e+06
# Penguin Books       1.897026e+06
# IKEA                1.887507e+06
# Zara                1.790721e+06
# Whirepool           1.456388e+06
# Mitsubhisi          4.533317e+05
# BlueStar            1.797543e+05
# Unknown             2.556424e+04

# %%
# 피드백 별 총 구매금액 비교
regular[:1]
# Out:
#    Transaction_ID(구매번호)  Customer_ID(고객번호)   City(시) State(주)  Zipcode(우편번호)  \
# 0               8691788              37249  Dortmund   Berlin          77985
#
#   Country(국가)  Age(나이) Gender(성별) Income(소득수준) Customer_Segment(소비등급)  \
# 0     Germany       21       Male          Low                Regular
#
#   Date(구매날짜)  Year(연도)   Month(월)  Time(시간)  Total_Purchases(총구매수)  \
# 0  9/18/2023      2023  September  22:03:55                    3.0
#
#    Amount(금액)  Total_Amount(총구매금액) Product_Category(카테고리) Product_Brand(브랜드)  \
# 0  108.028757            324.08627               Clothing               Nike
#
#   Product_Type(상품유형) Feedback(피드백) Shipping_Method(배송방법) Payment_Method(결제방법)  \
# 0             Shorts     Excellent              Same-Day           Debit Card
#
#   Order_Status(주문상태)  Ratings(평점)   products(상품명)
# 0            Shipped          5.0  Cycling shorts

# %%
regular.groupby('Feedback(피드백)')[['Total_Amount(총구매금액)']].sum().sort_values(by='Total_Amount(총구매금액)', ascending=False)
# Out:
#                Total_Amount(총구매금액)
# Feedback(피드백)
# Good                  6.226417e+07
# Excellent             5.873705e+07
# Average               4.521163e+07
# Bad                   3.359182e+07
# Unknown               1.609373e+05
